# %%
# !pip install webdriver-manager

# %%
import pandas as pd, requests
from io import StringIO
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %%
def GoogleDocsExtract(URL):
    # Extract the sheet ID from the URL
    sheet_id = link_href.split('/')[-2]

    # Construct the CSV export URL
    csv_url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv'

    # Send an HTTP GET request to fetch the CSV data
    response = requests.get(csv_url)

    if response.status_code == 200:
        # Read the CSV data into a pandas DataFrame
        df = pd.read_csv(StringIO(response.text))
        return df
    else:
        print(f"Failed to fetch data. Status code: {response.status_code}")

# %%
driver = webdriver.Chrome(service=Service(r'C:\Users\ahicks233\Documents\My Briefcase\Resources\Tech Files\chromedriver.exe'))
driver.get("https://cdle.colorado.gov/employers/layoff-separations/layoff-warn-list")
link_element = driver.find_element_by_link_text("View Real Time Warns")
link_href = link_element.get_attribute("href")
print(link_href)
# Out:
# C:\Users\ahicks233\AppData\Local\Temp\ipykernel_11728\3583413969.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\ahicks233\Documents\My Briefcase\Resources\Tech Files\chromedriver.exe')
# c:\Users\ahicks233\AppData\Local\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:492: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# https://docs.google.com/spreadsheets/d/1gsLtXhwCIqFUg1I9PZwX4hmSPmxi5ra4PmOzA99Eg28/edit?usp=sharing

# %%
GoogleDocsExtract(link_href)
df = df[['Company Name', 'WARN Date', 'Received', 'Total Layoffs', 'WARN Letter', 'NAICS', 'Workforce Area', '# Perm', '#Temp', 'Reduced Hours', '#Furloughs','Begin Date', 'End Date', 'Reason for Layoffs', 'Occupations Impacted']]
print(len(df))
df.head()
# Out:
# 85
#                      Company Name WARN Date Received  Total Layoffs  \
# 0             Wanzek Construction    1/3/23   1/3/23          666.0
# 1                        Gymshark    1/9/23  1/16/23           67.0
# 2  Specialized Bicycle Components   1/11/23   1/1123           15.0
# 3                   DCP Midstream   1/25/23  1/31/23          136.0
# 4                        Curaleaf   1/26/23  1/31/23           47.0
#
#                       WARN Letter                                NAICS  \
# 0             Wanzek Construction              Sector 23: Construction
# 1                        Gymshark             Sector 31: Manufacturing
# 2  Specialized Bicycle Components           Sector 42: Wholesale Trade
# 3                   DCP Midstream  Sector 22: Natural Gas Distribution
# 4                        Curaleaf             Sector 32: Manufacturing
#
#   Workforce Area  # Perm  #Temp  Reduced Hours  #Furloughs Begin Date  \
# ...

# %%
driver = webdriver.Chrome(service=Service(r'C:\Users\ahicks233\Documents\My Briefcase\Resources\Tech Files\chromedriver.exe'))
driver.get("https://cdle.colorado.gov/employers/layoff-separations/layoff-warn-list")
driver.find_element_by_class_name('ckeditor-accordion-toggle').click()

year = 2016
link_href = driver.find_element(By.LINK_TEXT, f"View {year} WARN List").get_attribute("href")
print(link_href)
# df = GoogleDocsExtract(link_href)
# df = df[['Company Name', 'WARN Date', 'Received', 'Total Layoffs', 'WARN Letter', 'NAICS', 'Workforce Area', '# Perm', '#Temp', 'Reduced Hours', '#Furloughs','Begin Date', 'End Date', 'Reason for Layoffs', 'Occupations Impacted']]
# print(len(df))
# df.head()
# df
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# c:\Users\ahicks233\Documents\My Briefcase\GitHub\Personal\Python\B2B Marketing Analytics\Data Ingestion\WARN.ipynb Cell 6 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/ahicks233/Documents/My%20Briefcase/GitHub/Personal/Python/B2B%20Marketing%20Analytics/Data%20Ingestion/WARN.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> driver.find_element_by_class_name('ckeditor-accordion-toggle').click()
#       <a href='vscode-notebook-cell:/c%3A/Users/ahicks233/Documents/My%20Briefcase/GitHub/Personal/Python/B2B%20Marketing%20Analytics/Data%20Ingestion/WARN.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> year = 2016
# ...

# %%
response = requests.get(link_href)
pd.read_csv(StringIO(response.text))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# c:\Users\ahicks233\Documents\My Briefcase\GitHub\Personal\Python\B2B Marketing Analytics\Data Ingestion\WARN.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/ahicks233/Documents/My%20Briefcase/GitHub/Personal/Python/B2B%20Marketing%20Analytics/Data%20Ingestion/WARN.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> response = requests.get(link_href)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ahicks233/Documents/My%20Briefcase/GitHub/Personal/Python/B2B%20Marketing%20Analytics/Data%20Ingestion/WARN.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a> pd.read_csv(StringIO(response.text))
#
# File c:\Users\ahicks233\AppData\Local\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
# ...

# %%
link_href
# Out:
# 'https://drive.google.com/open?id=1M-jYA2cSbehhp1pbpcAa900PtjAgktCHbU556cSjzc4'

# %%
driver = webdriver.Chrome(r'C:\Users\ahicks233\Documents\My Briefcase\Resources\Tech Files\chromedriver.exe')
driver.get("https://cdle.colorado.gov/employers/layoff-separations/layoff-warn-list")
driver.find_element_by_class_name('ckeditor-accordion-toggle').click()
link_href = driver.find_element_by_link_text(f"View {year} WARN List").get_attribute("href")
link_href
# Out:
# C:\Users\ahicks233\AppData\Local\Temp\ipykernel_11728\573331803.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\ahicks233\Documents\My Briefcase\Resources\Tech Files\chromedriver.exe')
# c:\Users\ahicks233\AppData\Local\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:652: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# 'https://docs.google.com/spreadsheets/d/1YPKuuH-bU2ARJjXkFufY3f8_S8pnLusHbBY0RtapE3M/edit?usp=sharing'

# %%
df = GoogleDocsExtract(link_href)
# Out:
#              Timestamp                 Email Address  \
# 0                  NaN                           NaN
# 1                  NaN                           NaN
# 2                  NaN                           NaN
# 3                  NaN                           NaN
# 4                  NaN                           NaN
# 5                  NaN                           NaN
# 6                  NaN                           NaN
# 7                  NaN                           NaN
# 8                  NaN                           NaN
# 9                  NaN                           NaN
# 10                 NaN                           NaN
# 11                 NaN                           NaN
# 12                 NaN                           NaN
# 13   2/11/2022 6:39:11         allofme0291@gmail.com
# 14  6/22/2022 12:35:36  ashj@totalenergysolutions.co
# 15  6/23/2022 10:38:53           PSANCHES@VIVAGE.COM
# 16                 NaN                           NaN
# ...
